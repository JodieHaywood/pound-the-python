# %% [markdown]
# ## This code is for perminatly adding paths to your ipython path

# %%
pathspec = r"""
# Generated by path-configurator.ipynb
# In the lines below, list the paths where Python should look for user-supplied modules,
# one directory per line.
#
# If a directory does not exist when Python is started, it will be ignored.
#
# For more information, see the documentation for the "site" package.
C:\Users\anorfleet\Documents\LiClipse Workspace\TeslaPyDev
C:\Users\anorfleet\Documents\LiClipse Workspace\NVHArchiveAnalysis
"""

# %%
import site, os
usp = site.getusersitepackages()
if not os.path.exists(usp):
    os.makedirs(usp)
uspfile = os.path.join(usp, 'userpaths.pth')
open(uspfile, 'w').write(pathspec)
print 'Wrote to ' + uspfile
# Out:
# Wrote to C:\Users\anorfleet\AppData\Roaming\Python\Python27\site-packages\userpaths.pth

# %% [markdown]
# ## Test to see what is in you path

# %%
import sys
sys.path
# Out:
# ['',
#  'C:\\Users\\anorfleet\\AppData\\Local\\Continuum\\Anaconda\\lib\\site-packages\\ggplot-0.5.9-py2.7.egg',
#  'C:\\Users\\anorfleet\\AppData\\Local\\Continuum\\Anaconda\\lib\\site-packages\\pymongo-2.7.1-py2.7-win-amd64.egg',
#  'C:\\Users\\anorfleet\\AppData\\Local\\Continuum\\Anaconda\\lib\\site-packages\\brewer2mpl-1.4-py2.7.egg',
#  'C:\\Users\\anorfleet\\AppData\\Local\\Continuum\\Anaconda\\lib\\site-packages\\seaborn-0.3.1-py2.7.egg',
#  'C:\\Users\\anorfleet\\AppData\\Local\\Continuum\\Anaconda\\lib\\site-packages\\pygeocoder-1.2.5-py2.7.egg',
#  'C:\\Users\\anorfleet\\AppData\\Local\\Continuum\\Anaconda\\lib\\site-packages\\simplejson-3.6.0-py2.7-win-amd64.egg',
#  'C:\\Users\\anorfleet\\AppData\\Local\\Continuum\\Anaconda\\lib\\site-packages\\pg8000-1.9.14-py2.7.egg',
#  'C:\\Users\\anorfleet\\AppData\\Local\\Continuum\\Anaconda\\lib\\site-packages\\pdftables-0.0.4-py2.7.egg',
# ...

# %% [markdown]
# ## Auto Reload funation to dynamitly edit code in an idea and run in ipython

# %%
#Automaticly loads functions imported with %aimport
# %load_ext autoreload
# %autoreload 1
# %aimport nvhBox

# %%
nvhBox.printHello()
# Out:
# hello my name is NVH Box And i need lots and lots of testing

# %%
#Info about the autoreload Function
# %autoreload?
